
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6      ['brain', 'liver', 'abdominal pain', 'parasite...
# 7                                                    NaN
# 8                                                    NaN
# 9      ['intestine', 'bacterial', 'viral', 'process',...
# 10     ['vibrio cholerae', 'leg', 'bacterium', 'atten...
# 11     ['vibrio cholerae', 'leg', 'bacterium', 'atten...
# 12     ['vibrio cholerae', 'leg', 'bacterium', 'atten...
# 13     ['vibrio cholerae', 'leg', 'bacterium', 'atten...
# 14                                                   NaN
# 15     ['consumption', 'febrile', 'salmonella', 'bact...
# 16     ['consumption', 'febrile', 'salmonella', 'bact...
# 17     ['consumption', 'febrile', 'salmonella', 'bact...
# 18     ['consumption', 'febrile', 'salmonella', 'bact...
# 19     ['consumption', 'febrile', 'salmonella', 'bact...
# 20     ['consumption', 'febrile', 'salmonella', 'bact...
# 21     ['consumption', 'febrile', 'salmonella', 'bact...
# 22     ['consumption', 'febrile', 'salmonella', 'bact...
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26     ['febrile', 'salmonella', 'severe', 'typhoid',...
# 27                                                   NaN
# 28      ['bacterium', 'salmonella', 'food', 'poisoning']
# 29                                                   NaN
# ...                                                  ...
# 40102                                                NaN
# 40103                                                NaN
# 40104                                                NaN
# 40105                                                NaN
# 40106                                                NaN
# 40107                                                NaN
# 40108                                                NaN
# 40109                                                NaN
# 40110                                                NaN
# 40111                                                NaN
# 40112                                                NaN
# 40113                                                NaN
# 40114                                                NaN
# 40115                                                NaN
# 40116                                                NaN
# 40117                                                NaN
# 40118                                                NaN
# 40119                                                NaN
# 40120                                                NaN
# 40121                                                NaN
# 40122                                                NaN
# 40123                                                NaN
# 40124                                                NaN
# 40125                                                NaN
# 40126                         ['limb', 'elbow', 'wrist']
# 40127                         ['limb', 'elbow', 'wrist']
# 40128                         ['limb', 'elbow', 'wrist']
# 40129                         ['limb', 'elbow', 'wrist']
# 40130                         ['limb', 'elbow', 'wrist']
# 40131                         ['limb', 'elbow', 'wrist']
#
# [40132 rows x 4 columns]

# %%
all_codes = []
for item in table["Unnamed: 0"]:
    all_codes.append(item.replace("-", ""))

# %%
all_billings = {}

# %%
for code in all_codes:
    billing_status = "Unknown"
    url = "https://icdlist.com/icd-10/%s" % code
    print(url)
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    stripped_code = code.replace(".", "")
    id_name = "icd-10-%s" % stripped_code
    print(id_name)
    if soup.find(id=id_name):
        if soup.find(id="smart-tags"):
            text = soup.find(id="smart-tags").get_text()
            if "Non-Billable" in text:
                billing_status = "Billable"
            elif "Billable" in text:
                billing_status = "Non-Billable"
    all_billings[code] = billing_status
# Out:
# https://icdlist.com/icd-10/A00
# icd-10-A00
# https://icdlist.com/icd-10/A01
# icd-10-A01
# https://icdlist.com/icd-10/A02
# icd-10-A02
# https://icdlist.com/icd-10/A03
# icd-10-A03
# https://icdlist.com/icd-10/A04
# icd-10-A04
# https://icdlist.com/icd-10/A05
# icd-10-A05
# https://icdlist.com/icd-10/A06
# icd-10-A06
# https://icdlist.com/icd-10/A07
# icd-10-A07
# https://icdlist.com/icd-10/A08
# icd-10-A08
# https://icdlist.com/icd-10/A09
# icd-10-A09
# https://icdlist.com/icd-10/A00
# icd-10-A00
# https://icdlist.com/icd-10/A00.0
# icd-10-A000
# https://icdlist.com/icd-10/A00.1
# icd-10-A001
# https://icdlist.com/icd-10/A00.9
# icd-10-A009
# https://icdlist.com/icd-10/A01
# icd-10-A01
# https://icdlist.com/icd-10/A01.0
# icd-10-A010
# https://icdlist.com/icd-10/A01.00
# icd-10-A0100
# https://icdlist.com/icd-10/A01.01
# https://icdlist.com/icd-10/A18.03
# icd-10-A1803
# https://icdlist.com/icd-10/A18.09
# icd-10-A1809
# https://icdlist.com/icd-10/A18.1
# icd-10-A181
# https://icdlist.com/icd-10/A18.10
# icd-10-A1810
# https://icdlist.com/icd-10/A18.11
# icd-10-A1811
# https://icdlist.com/icd-10/A18.12
# icd-10-A1812
# https://icdlist.com/icd-10/A18.13
# icd-10-A1813
# https://icdlist.com/icd-10/A18.14
# icd-10-A1814
# https://icdlist.com/icd-10/A18.15
# icd-10-A1815
# https://icdlist.com/icd-10/A18.16
# icd-10-A1816
# https://icdlist.com/icd-10/A18.17
# icd-10-A1817
# https://icdlist.com/icd-10/A18.18
# icd-10-A1818
# https://icdlist.com/icd-10/A18.2
# icd-10-A182
# https://icdlist.com/icd-10/A18.3
# icd-10-A183
# https://icdlist.com/icd-10/A18.31
# icd-10-A1831
# https://icdlist.com/icd-10/A18.32
# icd-10-A1832
# https://icdlist.com/icd-10/A18.39
# icd-10-A1839
# https://icdlist.com/icd-10/A18.4
# icd-10-A184
# https://icdlist.com/icd-10/A18.5
# icd-10-A185
# https://icdlist.com/icd-10/A18.50
# icd-10-A1850
# https://icdlist.com/icd-10/A18.51
# icd-10-A1851
# https://icdlist.com/icd-10/A18.52
# icd-10-A1852
# https://icdlist.com/icd-10/A18.53
# icd-10-A1853
# https://icdlist.com/icd-10/A18.54
# icd-10-A1854
# https://icdlist.com/icd-10/A18.59
# icd-10-A1859
# https://icdlist.com/icd-10/A18.6
# icd-10-A186
# https://icdlist.com/icd-10/A18.7
# icd-10-A187
# https://icdlist.com/icd-10/A18.8
# icd-10-A188
# https://icdlist.com/icd-10/A18.81
# icd-10-A1881
# https://icdlist.com/icd-10/A18.82
# icd-10-A1882
# https://icdlist.com/icd-10/A18.83
# icd-10-A1883
# https://icdlist.com/icd-10/A18.84
# icd-10-A1884
# https://icdlist.com/icd-10/A18.85
# icd-10-A1885
# https://icdlist.com/icd-10/A18.89
# icd-10-A1889
# https://icdlist.com/icd-10/A19
# icd-10-A19
# https://icdlist.com/icd-10/A19.0
# icd-10-A190
# https://icdlist.com/icd-10/A19.1
# icd-10-A191
# https://icdlist.com/icd-10/A19.2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-15cc5ad70525> in <module>
#       3     url = "https://icdlist.com/icd-10/%s" % code
#       4     print(url)
# ----> 5     page = requests.get(url)
#       6     soup = BeautifulSoup(page.content, 'html.parser')
#       7     stripped_code = code.replace(".", "")
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     704                 body=body,
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#     708
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         # Trigger any extra validation we need to do.
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#     384             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1008         # Force connect early to allow us to validate the connection.
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#    1012         if not conn.is_verified:
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     419             server_hostname=server_hostname,
#     420             ssl_context=context,
# --> 421             tls_in_tls=tls_in_tls,
#     422         )
#     423
#
# ~\Anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     427     if send_sni:
#     428         ssl_sock = _ssl_wrap_socket_impl(
# --> 429             sock, context, tls_in_tls, server_hostname=server_hostname
#     430         )
#     431     else:
#
# ~\Anaconda3\lib\site-packages\urllib3\util\ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     470
#     471     if server_hostname:
# --> 472         return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     473     else:
#     474         return ssl_context.wrap_socket(sock)
#
# ~\Anaconda3\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     405                          suppress_ragged_eofs=suppress_ragged_eofs,
#     406                          server_hostname=server_hostname,
# --> 407                          _context=self, _session=session)
#     408
#     409     def wrap_bio(self, incoming, outgoing, server_side=False,
#
# ~\Anaconda3\lib\ssl.py in __init__(self, sock, keyfile, certfile, server_side, cert_reqs, ssl_version, ca_certs, do_handshake_on_connect, family, type, proto, fileno, suppress_ragged_eofs, npn_protocols, ciphers, server_hostname, _context, _session)
#     815                         # non-blocking
#     816                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 817                     self.do_handshake()
#     818
#     819             except (OSError, ValueError):
#
# ~\Anaconda3\lib\ssl.py in do_handshake(self, block)
#    1075             if timeout == 0.0 and block:
#    1076                 self.settimeout(None)
# -> 1077             self._sslobj.do_handshake()
#    1078         finally:
#    1079             self.settimeout(timeout)
#
# ~\Anaconda3\lib\ssl.py in do_handshake(self)
#     687     def do_handshake(self):
#     688         """Start the SSL/TLS handshake."""
# --> 689         self._sslobj.do_handshake()
#     690         if self.context.check_hostname:
#     691             if not self.server_hostname:
#
# KeyboardInterrupt:

# %%
all_billings
# Out:
# {'A00': 'Billable',
#  'A01': 'Billable',
#  'A02': 'Billable',
#  'A03': 'Billable',
#  'A04': 'Billable'}
